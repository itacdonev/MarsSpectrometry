# %%
# %reload_ext autoreload
# %autoreload 2

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
## Environment
# Change main system path to be able to run code from src folder
import sys
p = sys.path[0]
# Mac OS
if sys.path[0].endswith('/models'):
    main_path = p[:-len('/models')]
sys.path[0] = main_path

import os, gc
from termcolor import colored
from tqdm import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import log_loss
from src import (config, fe, features, feature_selection, preprocess, training)
from src.fe import CreateFeatures
# Out:
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
# DATA PREPARATION
# ===== LOAD DATA ======
metadata = pd.read_csv(config.DATA_DIR + 'metadata.csv')
print(f'Metadata: {metadata.shape}')

train_labels = pd.read_csv(config.DATA_DIR + 'train_labels.csv')
print(f'Train labels: {train_labels.shape}')

valid_labels = pd.read_csv(config.DATA_DIR + 'val_labels.csv')
print(f'Train labels: {valid_labels.shape}')

# Combine train and valid labels
trvl_labels = pd.concat([train_labels, valid_labels], axis = 0)

submission = pd.read_csv(config.DATA_DIR + 'submission_format.csv')
print(f'Submission: {submission.shape}')

# ===== FILE PATHS OF SAMPLES =====
train_files = metadata[metadata.split == 'train']['features_path'].to_dict()
valid_files = metadata[metadata.split == 'val']['features_path'].to_dict()
test_files = metadata[metadata.split == 'test']['features_path'].to_dict()
# Train & Valid files
trva_files = train_files.copy()
trva_files.update(valid_files)
# All files
all_test_files = valid_files.copy()
all_test_files.update(test_files)

# Define SAM testbed files
sam_files = metadata[(metadata.instrument_type == 'sam_testbed') & (metadata.split == 'train')]['features_path']
sam_files = sam_files.to_dict()

# Get the names of the target columns in a list
target_labels_list = [i for i in train_labels.columns if i not in ['sample_id']]
print(f'Targets: {target_labels_list}')

# SAM testbed labels
sam_labels = train_labels.drop(train_labels.tail(len(sam_files)).index)
sam_labels = pd.concat([sam_labels, valid_labels], axis=0)
print(f'Labels w/o SAM : {sam_labels.shape}')
# Out:
# Metadata: (1570, 5)
# Train labels: (766, 11)
# Train labels: (293, 11)
# Submission: (804, 11)
# Targets: ['basalt', 'carbonate', 'chloride', 'iron_oxide', 'oxalate', 'oxychlorine', 'phyllosilicate', 'silicate', 'sulfate', 'sulfide']
# Labels w/o SAM : (1047, 11)

# %%
FTS_NAME = 'fts_mra_tempmz_cntpk_mratt_slope_spectra'   # Name of the file with features
COMPUTE_FTS = True                                      # Should the features be recomputed or combined
COMPUTE_FTS_SAM = False                                  # Compute SAM test bed
MODEL_ALGO = 'XGB_opt'                                  # Name of the classifier
MODEL_NAME = FTS_NAME + '_' + MODEL_ALGO                # Name of the model
COMBINE_FTS = ['fts_mra_tempmz_cntpk_mratt_slope', 'fts_mz_spectra']
FTS_SELECT = True

# %% [markdown]
# **COMPUTE FEATURES**
#
# - Change the `fe._` method depending on the feature that we wish to calculate

# %%
# Check if feature is computed and load it or choose to compute it
check_file = 0
for i in ['_tr', '_trvl', '_vlte']:
    check_file += os.path.exists(os.path.join(config.DATA_DIR_OUT, FTS_NAME +
                                              str(i) + '.csv'))

if (check_file == 3) & (not COMPUTE_FTS):
    print('Reading features ... ')
    X_tr = pd.read_csv(os.path.join(config.DATA_DIR_OUT, FTS_NAME + '_tr.csv'))
    print(X_tr.shape)
    X_trvl = pd.read_csv(os.path.join(config.DATA_DIR_OUT, FTS_NAME + '_trvl.csv'))
    print(X_trvl.shape)
    X_vlte = pd.read_csv(os.path.join(config.DATA_DIR_OUT, FTS_NAME + '_vlte.csv'))
    print(X_vlte.shape)
    
else:
    print('Computing features ... ')
    # ----- TRAIN -----
    fe = CreateFeatures(metadata, train_files, 'tr', FTS_NAME)
    X_tr = fe.combine_features(COMBINE_FTS)
    print(colored(f'train => {X_tr.shape}', 'blue'))
    
    # ----- TRAIN & VALID -----
    fe = CreateFeatures(metadata, trva_files, 'trvl', FTS_NAME)
    X_trvl = fe.combine_features(COMBINE_FTS)
    print(colored(f'train => {X_trvl.shape}', 'blue'))
    
    # ----- VALID & TEST -----
    fe = CreateFeatures(metadata, all_test_files, 'vlte', FTS_NAME)
    X_vlte = fe.combine_features(COMBINE_FTS)
    print(colored(f'train => {X_vlte.shape}', 'blue'))
    
if COMPUTE_FTS_SAM:
    print(f'\nCreating SAM testbed samples ...')
    # Training without SAM testbed
    X_tr_sam = X_tr.drop(X_tr.tail(len(sam_files)).index).copy()
    X_tr_sam = pd.concat([X_tr_sam, X_trvl.iloc[len(train_files):,:]], axis=0)
    print(f'Train shape: {X_tr_sam.shape}')
    # Validation data
    X_vl_sam = X_tr.tail(len(sam_files)).copy()
    print(f'Valid shape: {X_vl_sam.shape}')
# Out:
# Computing features ...
# train => (766, 10)
# train => (1059, 10)
# train => (804, 10)

# %% [markdown]
# ## MODELS

# %% [markdown]
# **TRAIN**

# %%
if FTS_SELECT:
    _, SFM_COLUMNS = feature_selection.fts_select(
        target_labels_list, FTS_NAME, MODEL_NAME, MODEL_ALGO, 'tr',
        X_tr, X_vlte, train_labels, valid_files, valid_labels
    )
else:
    SFM_COLUMNS = None
# Out:
# Reading columns from ../models/fts_mra_tempmz_cntpk_mratt_slope_spectra_tr_SFM_COLS.txt

# %%
for label in target_labels_list:
    print(f'{label}: {len(SFM_COLUMNS[label])}')
# Out:
# basalt: 143
# carbonate: 220
# chloride: 108
# iron_oxide: 159
# oxalate: 1991
# oxychlorine: 1991
# phyllosilicate: 1991
# silicate: 263
# sulfate: 231
# sulfide: 41

# %%
# ===== TRAIN =====
cvloss, submission_model = training.train_tbl(
    df_train=X_tr,
    df_labels=train_labels,
    target_list=target_labels_list,
    df_test=X_vlte,
    model_algo=MODEL_ALGO,
    sub_name=MODEL_NAME + '_tr',
    fts_select_cols=SFM_COLUMNS,
    )

# Compute validation loss when full model is trained
mloss, mloss_avg = training.compute_valid_loss(submission_model,
                                               valid_files, valid_labels,
                                               target_labels_list,
                                               sub_name=MODEL_NAME + '_tr',
                                               fts_select_cols=True)
# Out:
# CV training ....
# basalt
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/models/fts_mra_tempmz_cntpk_mratt_slope_spectra_XGB_opt_sfm.ipynb Cell 11' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/models/fts_mra_tempmz_cntpk_mratt_slope_spectra_XGB_opt_sfm.ipynb#ch0000010?line=0'>1</a> # ===== TRAIN =====
# ----> <a href='vscode-notebook-cell:/Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/models/fts_mra_tempmz_cntpk_mratt_slope_spectra_XGB_opt_sfm.ipynb#ch0000010?line=1'>2</a> cvloss, submission_model = training.train_tbl(
#       <a href='vscode-notebook-cell:/Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/models/fts_mra_tempmz_cntpk_mratt_slope_spectra_XGB_opt_sfm.ipynb#ch0000010?line=2'>3</a>     df_train=X_tr,
#       <a href='vscode-notebook-cell:/Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/models/fts_mra_tempmz_cntpk_mratt_slope_spectra_XGB_opt_sfm.ipynb#ch0000010?line=3'>4</a>     df_labels=train_labels,
#       <a href='vscode-notebook-cell:/Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/models/fts_mra_tempmz_cntpk_mratt_slope_spectra_XGB_opt_sfm.ipynb#ch0000010?line=4'>5</a>     target_list=target_labels_list,
#       <a href='vscode-notebook-cell:/Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/models/fts_mra_tempmz_cntpk_mratt_slope_spectra_XGB_opt_sfm.ipynb#ch0000010?line=5'>6</a>     df_test=X_vlte,
#       <a href='vscode-notebook-cell:/Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/models/fts_mra_tempmz_cntpk_mratt_slope_spectra_XGB_opt_sfm.ipynb#ch0000010?line=6'>7</a>     model_algo=MODEL_ALGO,
#       <a href='vscode-notebook-cell:/Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/models/fts_mra_tempmz_cntpk_mratt_slope_spectra_XGB_opt_sfm.ipynb#ch0000010?line=7'>8</a>     sub_name=MODEL_NAME + '_tr',
#       <a href='vscode-notebook-cell:/Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/models/fts_mra_tempmz_cntpk_mratt_slope_spectra_XGB_opt_sfm.ipynb#ch0000010?line=8'>9</a>     fts_select_cols=SFM_COLUMNS,
#      <a href='vscode-notebook-cell:/Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/models/fts_mra_tempmz_cntpk_mratt_slope_spectra_XGB_opt_sfm.ipynb#ch0000010?line=9'>10</a>     )
#      <a href='vscode-notebook-cell:/Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/models/fts_mra_tempmz_cntpk_mratt_slope_spectra_XGB_opt_sfm.ipynb#ch0000010?line=11'>12</a> # Compute validation loss when full model is trained
#      <a href='vscode-notebook-cell:/Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/models/fts_mra_tempmz_cntpk_mratt_slope_spectra_XGB_opt_sfm.ipynb#ch0000010?line=12'>13</a> mloss, mloss_avg = training.compute_valid_loss(submission_model,
#      <a href='vscode-notebook-cell:/Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/models/fts_mra_tempmz_cntpk_mratt_slope_spectra_XGB_opt_sfm.ipynb#ch0000010?line=13'>14</a>                                                valid_files, valid_labels,
#      <a href='vscode-notebook-cell:/Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/models/fts_mra_tempmz_cntpk_mratt_slope_spectra_XGB_opt_sfm.ipynb#ch0000010?line=14'>15</a>                                                target_labels_list,
#      <a href='vscode-notebook-cell:/Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/models/fts_mra_tempmz_cntpk_mratt_slope_spectra_XGB_opt_sfm.ipynb#ch0000010?line=15'>16</a>                                                sub_name=MODEL_NAME + '_tr',
#      <a href='vscode-notebook-cell:/Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/models/fts_mra_tempmz_cntpk_mratt_slope_spectra_XGB_opt_sfm.ipynb#ch0000010?line=16'>17</a>                                                fts_select_cols=True)
#
# File ~/Documents/PROJECTS/MarsSpectrometry/src/training.py:410, in train_tbl(df_train, df_labels, target_list, df_test, model_algo, sub_name, target_encode, target_encode_fts, verbose, test_sam, fts_select_cols)
#     <a href='file:///Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/src/training.py?line=407'>408</a> # CV TRAINING
#     <a href='file:///Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/src/training.py?line=408'>409</a> print(colored('CV training ....', 'blue'))
# --> <a href='file:///Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/src/training.py?line=409'>410</a> train_cv_loss = trainCV_label(X=df_train,
#     <a href='file:///Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/src/training.py?line=410'>411</a>                               df_y=df_labels,
#     <a href='file:///Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/src/training.py?line=411'>412</a>                               target=target_list,
#     <a href='file:///Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/src/training.py?line=412'>413</a>                               cv_folds=config.NO_CV_FOLDS,
#     <a href='file:///Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/src/training.py?line=413'>414</a>                               model_metric=log_loss,
#     <a href='file:///Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/src/training.py?line=414'>415</a>                               model_algo=model_algo,
#     <a href='file:///Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/src/training.py?line=415'>416</a>                               target_encode=target_encode,
#     <a href='file:///Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/src/training.py?line=416'>417</a>                               verbose=verbose,
#     <a href='file:///Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/src/training.py?line=417'>418</a>                               target_encode_fts=target_encode_fts,
#     <a href='file:///Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/src/training.py?line=418'>419</a>                               fts_select_cols=fts_select_cols)
#     <a href='file:///Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/src/training.py?line=420'>421</a> train_cv_loss_df = pd.DataFrame.from_dict(train_cv_loss, orient='index')
#     <a href='file:///Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/src/training.py?line=421'>422</a> if fts_select_cols:
#
# File ~/Documents/PROJECTS/MarsSpectrometry/src/training.py:199, in trainCV_label(X, df_y, target, cv_folds, model_metric, model_algo, verbose, target_encode, target_encode_fts, fts_select_cols)
#     <a href='file:///Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/src/training.py?line=196'>197</a> if fts_select_cols:
#     <a href='file:///Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/src/training.py?line=197'>198</a>     fts_columns = fts_select_cols[label]
# --> <a href='file:///Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/src/training.py?line=198'>199</a>     Xtrain = Xtrain[fts_columns].copy()
#     <a href='file:///Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/src/training.py?line=199'>200</a>     Xvalid = Xvalid[fts_columns].copy()
#     <a href='file:///Users/itacdonev/Documents/PROJECTS/MarsSpectrometry/src/training.py?line=201'>202</a> # Initialize the classifier
#
# File ~/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    <a href='file:///Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/pandas/core/frame.py?line=3508'>3509</a>     if is_iterator(key):
#    <a href='file:///Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/pandas/core/frame.py?line=3509'>3510</a>         key = list(key)
# -> <a href='file:///Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/pandas/core/frame.py?line=3510'>3511</a>     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    <a href='file:///Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/pandas/core/frame.py?line=3512'>3513</a> # take() does not accept boolean indexers
#    <a href='file:///Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/pandas/core/frame.py?line=3513'>3514</a> if getattr(indexer, "dtype", None) == bool:
#
# File ~/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/pandas/core/indexes/base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    <a href='file:///Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=5778'>5779</a> else:
#    <a href='file:///Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=5779'>5780</a>     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> <a href='file:///Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=5781'>5782</a> self._raise_if_missing(keyarr, indexer, axis_name)
#    <a href='file:///Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=5783'>5784</a> keyarr = self.take(indexer)
#    <a href='file:///Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=5784'>5785</a> if isinstance(key, Index):
#    <a href='file:///Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=5785'>5786</a>     # GH 42790 - Preserve name from an Index
#
# File ~/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/pandas/core/indexes/base.py:5845, in Index._raise_if_missing(self, key, indexer, axis_name)
#    <a href='file:///Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=5841'>5842</a>     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    <a href='file:///Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=5843'>5844</a> not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> <a href='file:///Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=5844'>5845</a> raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Ion_0.0_0_100', 'Ion_0.0_400_500', 'Ion_0.0_500_600', 'Ion_0.0_800_900', 'Ion_0.0_1200_1300', 'Ion_1.0_600_700', 'Ion_2.0_0_100', 'Ion_2.0_100_200', 'Ion_2.0_300_400', 'Ion_2.0_500_600', 'Ion_5.0_100_200', 'Ion_7.0_800_900', 'Ion_11.0_1000_1100', 'Ion_12.0_0_100', 'Ion_12.0_300_400', 'Ion_12.0_600_700', 'Ion_13.0_300_400', 'Ion_14.0_0_100', 'Ion_16.0_300_400', 'Ion_16.0_600_700', 'Ion_16.0_800_900', 'Ion_16.0_1000_1100', 'Ion_17.0_200_300', 'Ion_17.0_300_400', 'Ion_17.0_600_700', 'Ion_17.0_900_1000', 'Ion_17.0_1200_1300', 'Ion_18.0_200_300', 'Ion_18.0_300_400', 'Ion_18.0_400_500', 'Ion_18.0_600_700', 'Ion_18.0_700_800', 'Ion_18.0_800_900', 'Ion_18.0_900_1000', 'Ion_19.0_700_800', 'Ion_19.0_900_1000', 'Ion_20.0_200_300', 'Ion_20.0_900_1000', 'Ion_21.0_100_200', 'Ion_22.0_300_400', 'Ion_23.0_0_100', 'Ion_24.0_200_300', 'Ion_24.0_1000_1100', 'Ion_25.0_100_200', 'Ion_25.0_300_400', 'Ion_26.0_600_700', 'Ion_27.0_400_500', 'Ion_27.0_700_800', 'Ion_28.0_200_300', 'Ion_28.0_300_400', 'Ion_29.0_0_100', 'Ion_30.0_0_100', 'Ion_31.0_300_400', 'Ion_31.0_400_500', 'Ion_31.0_500_600', 'Ion_31.0_1200_1300', 'Ion_32.0_600_700', 'Ion_32.0_700_800', 'Ion_32.0_1200_1300', 'Ion_34.0_100_200', 'Ion_34.0_600_700', 'Ion_35.0_400_500', 'Ion_35.0_600_700', 'Ion_35.0_900_1000', 'Ion_36.0_700_800', 'Ion_36.0_1200_1300', 'Ion_37.0_900_1000', 'Ion_37.0_1000_1100', 'Ion_38.0_100_200', 'Ion_38.0_200_300', 'Ion_38.0_1200_1300', 'Ion_41.0_100_200', 'Ion_43.0_200_300', 'Ion_44.0_0_100', 'Ion_44.0_100_200', 'Ion_44.0_300_400', 'Ion_45.0_0_100', 'Ion_45.0_800_900', 'Ion_46.0_300_400', 'Ion_46.0_500_600', 'Ion_47.0_200_300', 'Ion_47.0_400_500', 'Ion_47.0_900_1000', 'Ion_47.0_1100_1200', 'Ion_48.0_500_600', 'Ion_48.0_700_800', 'Ion_48.0_900_1000', 'Ion_48.0_1100_1200', 'Ion_48.0_1200_1300', 'Ion_50.0_200_300', 'Ion_50.0_400_500', 'Ion_52.0_200_300', 'Ion_54.0_600_700', 'Ion_56.0_500_600', 'Ion_63.0_500_600', 'Ion_64.0_0_100', 'Ion_64.0_100_200', 'Ion_64.0_700_800', 'Ion_64.0_900_1000', 'Ion_66.0_1000_1100', 'Ion_67.0_500_600', 'Ion_74.0_600_700', 'Ion_94.0_1200_1300', 'Ion_97.0_900_1000', 'peak_cnt_43.0', 'peak_cnt_74.0', 'peak_time_1.0', 'peak_time_13.0', 'peak_time_17.0', 'peak_time_26.0', 'peak_time_28.0', 'peak_time_29.0', 'peak_time_32.0', 'peak_time_43.0', 'peak_time_44.0', 'peak_time_47.0', 'peak_time_76.0', 'peak_time_85.0', 'peak_temp_12.0', 'peak_temp_44.0', 'peak_temp_56.0', 'peak_temp_62.0', 'peak_temp_64.0', 'peak_temp_85.0', 'peak_abund_14.0', 'peak_abund_18.0', 'peak_abund_24.0', 'peak_abund_30.0', 'peak_abund_31.0', 'peak_abund_32.0', 'peak_abund_33.0', 'peak_abund_43.0', 'peak_abund_46.0', 'peak_abund_48.0', 'peak_abund_59.0', 'peak_abund_70.0', 'peak_abund_76.0', 'peak_abund_81.0', 'slope_tt'] not in index"

# %%
print(f'CV Logloss: {np.mean(list(cvloss.values()))}')
print(f'VALID FM LogLoss: {mloss_avg}')
print(f'CV logLoss Label')
print(cvloss)
# Out:
# CV Logloss: 0.15476132326442846
# VALID FM LogLoss: 0.15374808633853382
# CV logLoss Label
# {'basalt': 0.14787643638480896, 'carbonate': 0.12361431972609915, 'chloride': 0.17835871351192956, 'iron_oxide': 0.23414320543591255, 'oxalate': 0.014486072301787317, 'oxychlorine': 0.1588819542286757, 'phyllosilicate': 0.23647077978903233, 'silicate': 0.18902406531295024, 'sulfate': 0.20727511739910104, 'sulfide': 0.05748256855398783}

# %% [markdown]
# **TRAIN & VALID**

# %%
# ===== TRAIN =====
cvloss, submission_model = training.train_tbl(
    df_train=X_trvl,
    df_labels=trvl_labels,
    target_list=target_labels_list,
    df_test=X_vlte,
    model_algo=MODEL_ALGO,
    sub_name=MODEL_NAME + '_trvl'
    )
# Out:
# CV training ....
# basalt
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# carbonate
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# chloride
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# iron_oxide
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# oxalate
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# oxychlorine
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# phyllosilicate
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# silicate
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# sulfate
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# sulfide
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# Full training .....
# LABEL: basalt
# /Users/itacdonev/opt/miniconda3/envs/nasamars/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# LABEL: carbonate
# LABEL: chloride
# LABEL: iron_oxide
# LABEL: oxalate
# LABEL: oxychlorine
# LABEL: phyllosilicate
# LABEL: silicate
# LABEL: sulfate
# LABEL: sulfide
# Average Log Loss: 0.1423
# Log Loss per Label:
# {'basalt': 0.14454150217684264, 'carbonate': 0.08635449306652845, 'chloride': 0.1692469494765426, 'iron_oxide': 0.2092332869874621, 'oxalate': 0.012537570247599838, 'oxychlorine': 0.1408598591270323, 'phyllosilicate': 0.2291803502641357, 'silicate': 0.18686892932007956, 'sulfate': 0.17470823987189277, 'sulfide': 0.06963498027163063}

# %%
print(f'CV Logloss: {np.mean(list(cvloss.values()))}')
print(f'CV logLoss Label')
print(cvloss)
# Out:
# CV Logloss: 0.14231661608097465
# CV logLoss Label
# {'basalt': 0.14454150217684264, 'carbonate': 0.08635449306652845, 'chloride': 0.1692469494765426, 'iron_oxide': 0.2092332869874621, 'oxalate': 0.012537570247599838, 'oxychlorine': 0.1408598591270323, 'phyllosilicate': 0.2291803502641357, 'silicate': 0.18686892932007956, 'sulfate': 0.17470823987189277, 'sulfide': 0.06963498027163063}

# %% [markdown]
# **SAM TRAINING**

# %%
# ===== TRAIN SAM =====
cvloss, submission_model = training.train_tbl(
    df_train=X_tr_sam,
    df_labels=sam_labels,
    target_list=target_labels_list,
    df_test=X_vl_sam,
    model_algo=MODEL_ALGO,
    sub_name=MODEL_NAME + '_sam',
    test_sam=True
    )

# Compute validation loss when full model is trained
mloss, mloss_avg = training.compute_valid_loss(submission_model,
                                               sam_files, sam_labels,
                                               target_labels_list,
                                               sub_name=MODEL_NAME + '_sam')

# %%
print(f'CV Logloss: {np.mean(list(cvloss.values()))}')
print(f'VALID FM LogLoss: {mloss_avg}')
print(f'CV logLoss Label')
print(cvloss)
